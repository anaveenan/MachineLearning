# %% [markdown]
# #DATASCI W261: Machine Learning at Scale

# %% [markdown]
# ##Linear regresssion through gradient desecnt method

# %% [markdown]
# # Data Generation

# %% [markdown]
# Data Information:
# + Sizes: 1000 points
# + True model: y = 1.0 * x - 4
# + Noise：Normal Distributed mean = 0, var = 0.5

# %%
 # %matplotlib inline
import numpy as np
import pylab 
size = 1000
x = np.random.uniform(-4, 4, size)
y = x * 1.0 - 4 + np.random.normal(0,0.5,size)
data = zip(y,x)
np.savetxt('LinearRegression.csv',data,delimiter = ",")

# %% [markdown]
# # Data Visualiazation

# %%
pylab.plot(x, y,'*')
pylab.show()

# %% [markdown]
# # MrJob class Code

# %% [markdown]
# Objective function:
# $ Q_{ui} = \cases{
# r &  if user u rate item i \cr
# 0 & if user u did not rate item i
# } $

# %%
# %%writefile MrJobBatchGDUpdate_LinearRegression.py
from mrjob.job import MRJob

# This MrJob calculates the gradient of the entire training set 
#     Mapper: calculate partial gradient for each example  
#     
class MrJobBatchGDUpdate_LinearRegression(MRJob):
    # run before the mapper processes any input

    
    #load linear regession model file
    def read_weightsfile(self):
        # Read weights file
        #recordStrs = [s.split('\n')[0].split('\t') for s in open("model").readlines()]
        with open('weights.txt', 'r') as f:
            self.weights = [float(v) for v in f.readline().split(',')]
        # Initialze gradient for this iteration
        self.partial_Gradient = [0]*len(self.weights)
        self.partial_count = 0
    
        
    # MAPPER Calculate partial gradient for each example 
    def partial_gradient(self, _, line):
        D = (map(float,line.split(',')))
        # y_hat is the predicted value given current weights
        y_hat = self.weights[0]+self.weights[1]*D[1]
        # Update parial gradient vector with gradient form current example
        yield None, (D[0]-y_hat,(D[0]-y_hat)*D[1],1)
    
  
        
    # REDUCER Accumulate partial gradient from mapper and emit total gradient 
    # Output: key = None, Value = gradient vector
    def gradient_accumulater(self, _, partial_Gradient_Record): 
        total_gradient = [0]*2
        total_count = 0
        for partial_Gradient,partial_count in partial_Gradient_Record:
            total_count = total_count + partial_count
            total_gradient[0] = total_gradient[0] + partial_Gradient[0]
            total_gradient[1] = total_gradient[1] + partial_Gradient[1]
        yield None, [v/total_count for v in total_gradient]
    
    def steps(self):
        return [self.mr(mapper_init=self.read_weightsfile,
                       mapper=self.partial_gradient,
                       #mapper_final=self.partial_gradient_emit,
                       reducer=self.gradient_accumulater)] 
    

    # Calculate partial gradient for each example 
    def partial_gradient_InMemoryCombiner(self, _, line):
        D = (map(float,line.split(',')))
        # y_hat is the predicted value given current weights
        y_hat = self.weights[0]+self.weights[1]*D[1]
        # Update parial gradient vector with gradient form current example
        self.partial_Gradient =  [self.partial_Gradient[0]+ D[0]-y_hat, self.partial_Gradient[1]+(D[0]-y_hat)*D[1]]
        self.partial_count = self.partial_count + 1
        #yield None, (D[0]-y_hat,(D[0]-y_hat)*D[1],1)
    # Finally emit in-memory partial gradient and partial count
    def partial_gradient_emit(self):
        yield None, (self.partial_Gradient,self.partial_count)
        
     
    
    
if __name__ == '__main__':
    MrJobBatchGDUpdate_LinearRegression.run()
# Out:
# Overwriting MrJobBatchGDUpdate_LinearRegression.py

# %% [markdown]
# # Driver Code

# %% [markdown]
# **Linear regression via gradient descent**
# **Objective Function:**
# $$ Minimize (\textbf{Y} - \textbf{X}\beta)^2 $$
#
# **Gradient Function:**
# $$ Minimize 2(\textbf{Y} - \textbf{X}\beta)\textbf{X} $$

# %%
# !pwd 
# !ls -l LinearRegression.csv
# Out:
# /Users/jshanahan/Dropbox/Projects/Target-2016-04/Classes/Lecture-09-Linear-Regression
# -rw-r--r--@ 1 jshanahan  staff  51477 Jun 22 15:51 LinearRegression.csv

# %%
# !cat  weights.txt
# Out:
# -1.02277918281,-0.479630918679

# %%
from numpy import random,array
from MrJobBatchGDUpdate_LinearRegression import MrJobBatchGDUpdate_LinearRegression

learning_rate = 0.05
stop_criteria = 0.000005

# Generate random values as inital weights
weights = array([random.uniform(-3,3),random.uniform(-3,3)])
# Write the weights to the files
with open('weights.txt', 'w') as f:
    f.writelines(','.join(str(j) for j in weights))

# create a mrjob instance for batch gradient descent update over all data
mr_job = MrJobBatchGDUpdate_LinearRegression(args=['LinearRegression.csv', '--file=weights.txt'])
# Update centroids iteratively
i = 0
while(1):
    print "iteration ="+str(i)+"  weights =",weights
    # Save weights from previous iteration
    weights_old = weights
    with mr_job.make_runner() as runner: 
        runner.run()
        # stream_output: get access of the output 
        for line in runner.stream_output():
            # value is the gradient value
            key,value =  mr_job.parse_output_line(line)
            # Update weights
            weights = weights + learning_rate*array(value)
    i = i + 1
    # Write the updated weights to file 
    with open('weights.txt', 'w') as f:
        f.writelines(','.join(str(j) for j in weights))
    # Stop if weights get converged
    if(sum((weights_old-weights)**2)<stop_criteria):
        break
        
print "Final weights\n"
print weights
# Out:
# iteration =0  weights = [ 0.90013981  2.88018202]
# iteration =1  weights = [ 0.65784615  2.38344165]
# iteration =2  weights = [ 0.42678641  2.02000762]
# iteration =3  weights = [ 0.20663527  1.75401018]
# iteration =4  weights = [-0.00297994  1.55923612]
# iteration =5  weights = [-0.20245974  1.41652884]
# iteration =6  weights = [-0.39221859  1.31188853]
# iteration =7  weights = [-0.57267502  1.23508377]
# iteration =8  weights = [-0.74424481  1.17863697]
# iteration =9  weights = [-0.90733619  1.13708297]
# iteration =10  weights = [-1.06234669  1.10642726]
# iteration =11  weights = [-1.20966101  1.08375005]
# iteration =12  weights = [-1.34964983  1.06691696]
# iteration =13  weights = [-1.48266905  1.05436759]
# iteration =14  weights = [-1.60905956  1.044961  ]
# iteration =15  weights = [-1.72914722  1.03786281]
# iteration =16  weights = [-1.84324309  1.03246273]
# iteration =17  weights = [-1.95164374  1.02831419]
# iteration =18  weights = [-2.05463171  1.02509036]
# iteration =19  weights = [-2.152476    1.02255186]
# iteration =20  weights = [-2.24543257  1.02052331]
# iteration =21  weights = [-2.33374491  1.01887608]
# iteration =22  weights = [-2.41764456  1.01751575]
# iteration =23  weights = [-2.49735164  1.01637289]
# iteration =24  weights = [-2.57307538  1.0153964 ]
# iteration =25  weights = [-2.64501468  1.01454854]
# iteration =26  weights = [-2.71335851  1.0138014 ]
# iteration =27  weights = [-2.77828647  1.01313423]
# iteration =28  weights = [-2.83996922  1.01253156]
# iteration =29  weights = [-2.8985689   1.01198177]
# iteration =30  weights = [-2.95423957  1.01147611]
# iteration =31  weights = [-3.00712761  1.01100787]
# iteration =32  weights = [-3.05737207  1.01057192]
# iteration =33  weights = [-3.10510508  1.01016425]
# iteration =34  weights = [-3.15045217  1.00978171]
# iteration =35  weights = [-3.19353257  1.00942175]
# iteration =36  weights = [-3.2344596   1.00908232]
# iteration =37  weights = [-3.27334088  1.00876171]
# iteration =38  weights = [-3.31027866  1.00845847]
# iteration =39  weights = [-3.34537009  1.00817138]
# iteration =40  weights = [-3.37870746  1.00789937]
# iteration =41  weights = [-3.41037844  1.00764148]
# iteration =42  weights = [-3.44046633  1.00739686]
# iteration =43  weights = [-3.46905026  1.00716476]
# iteration =44  weights = [-3.4962054   1.00694446]
# iteration =45  weights = [-3.52200318  1.00673532]
# iteration =46  weights = [-3.54651144  1.00653675]
# iteration =47  weights = [-3.56979464  1.00634819]
# iteration =48  weights = [-3.59191401  1.00616911]
# iteration =49  weights = [-3.61292773  1.00599902]
# iteration =50  weights = [-3.63289107  1.00583746]
# iteration =51  weights = [-3.65185653  1.00568401]
# iteration =52  weights = [-3.66987398  1.00553824]
# iteration =53  weights = [-3.68699082  1.00539977]
# iteration =54  weights = [-3.70325207  1.00526823]
# iteration =55  weights = [-3.71870048  1.00514328]
# iteration =56  weights = [-3.7333767   1.00502457]
# iteration =57  weights = [-3.74731932  1.0049118 ]
# iteration =58  weights = [-3.760565    1.00480467]
# iteration =59  weights = [-3.7731486  1.0047029]
# iteration =60  weights = [-3.78510319  1.00460621]
# iteration =61  weights = [-3.79646022  1.00451436]
# iteration =62  weights = [-3.80724957  1.0044271 ]
# iteration =63  weights = [-3.8174996   1.00434421]
# iteration =64  weights = [-3.82723728  1.00426545]
# iteration =65  weights = [-3.83648821  1.00419064]
# iteration =66  weights = [-3.84527673  1.00411956]
# iteration =67  weights = [-3.85362595  1.00405204]
# iteration =68  weights = [-3.86155783  1.00398789]
# iteration =69  weights = [-3.86909323  1.00392695]
# iteration =70  weights = [-3.87625196  1.00386906]
# iteration =71  weights = [-3.88305287  1.00381405]
# iteration =72  weights = [-3.88951382  1.0037618 ]
# iteration =73  weights = [-3.89565182  1.00371216]
# iteration =74  weights = [-3.90148301  1.003665  ]
# iteration =75  weights = [-3.90702272  1.0036202 ]
# iteration =76  weights = [-3.91228553  1.00357764]
# iteration =77  weights = [-3.91728527  1.00353721]
# iteration =78  weights = [-3.92203509  1.00349879]
# iteration =79  weights = [-3.92654749  1.0034623 ]
# iteration =80  weights = [-3.93083434  1.00342763]
# iteration =81  weights = [-3.93490691  1.0033947 ]
# iteration =82  weights = [-3.9387759   1.00336341]
# iteration =83  weights = [-3.94245151  1.00333368]
# iteration =84  weights = [-3.94594338  1.00330544]
# iteration =85  weights = [-3.94926071  1.00327861]
# iteration =86  weights = [-3.95241222  1.00325313]
# iteration =87  weights = [-3.9554062   1.00322891]
# iteration =88  weights = [-3.95825053  1.00320591]
# iteration =89  weights = [-3.96095268  1.00318406]
# iteration =90  weights = [-3.96351976  1.0031633 ]
# iteration =91  weights = [-3.96595852  1.00314357]
# iteration =92  weights = [-3.96827538  1.00312484]
# Final weights
#
# [-3.97047643  1.00310704]

# %%
pwd
# Out:
# u'/Users/jshanahan/Dropbox/Projects/Target-2016-04/Classes/Lecture-09-Linear-Regression'

# %%
 # %matplotlib inline
import numpy as np
import pylab 

size = 1000
x = np.random.uniform(-4, 4, size)
y = x * 1.0 - 4 + np.random.normal(0,0.5,size)
data = zip(y,x)

pylab.plot(x, y,'*')
pylab.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-19c0d4f6b36f> in <module>()
#       2 import numpy as np
#       3 import pylab
# ----> 4 pylab.plot(x, y,'*')
#       5 pylab.show()
#
# NameError: name 'x' is not defined
